# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек.--Считывание-данных-из-исходных-файлов" data-toc-modified-id="Импорт-библиотек.--Считывание-данных-из-исходных-файлов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек.  Считывание данных из исходных файлов</a></span></li><li><span><a href="#Общий-обзор-данных" data-toc-modified-id="Общий-обзор-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Общий обзор данных</a></span></li><li><span><a href="#Названия-столбцов" data-toc-modified-id="Названия-столбцов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Названия столбцов</a></span></li><li><span><a href="#Преобразование--типов-данных" data-toc-modified-id="Преобразование--типов-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Преобразование  типов данных</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li><li><span><a href="#Обзор-данных-датасета" data-toc-modified-id="Обзор-данных-датасета-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Обзор данных датасета</a></span></li></ul></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма-(скользящее-среднее)" data-toc-modified-id="Функция-для-сглаживания-фрейма-(скользящее-среднее)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма (скользящее среднее)</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Распределение-пользователей-по-странам" data-toc-modified-id="Распределение-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение пользователей по странам</a></span></li><li><span><a href="#Распределение-пользователей-по-устройствам" data-toc-modified-id="Распределение-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Распределение пользователей по устройствам</a></span></li><li><span><a href="#Рекламные-источники-привлечения-пользователей" data-toc-modified-id="Рекламные-источники-привлечения-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Рекламные источники привлечения пользователей</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общие-расходы-на-маркетинг" data-toc-modified-id="Общие-расходы-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общие расходы на маркетинг</a></span></li><li><span><a href="#Распределение-расходов-на-маркетинг-по-рекламным-источникам" data-toc-modified-id="Распределение-расходов-на-маркетинг-по-рекламным-источникам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Распределение расходов на маркетинг по рекламным источникам</a></span></li><li><span><a href="#Динамика-расходов-на-маркетинг-по-неделям-и-месяцам" data-toc-modified-id="Динамика-расходов-на-маркетинг-по-неделям-и-месяцам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Динамика расходов на маркетинг по неделям и месяцам</a></span></li><li><span><a href="#Средняя-стоимость--привлечения-одного-пользователя-(САС)-по-каналам" data-toc-modified-id="Средняя-стоимость--привлечения-одного-пользователя-(САС)-по-каналам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средняя стоимость  привлечения одного пользователя (САС) по каналам</a></span></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Графики---LTV,-CAC,-ROI.----Окупаемость-рекламы." data-toc-modified-id="Графики---LTV,-CAC,-ROI.----Окупаемость-рекламы.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Графики   LTV, CAC, ROI.    Окупаемость рекламы.</a></span></li><li><span><a href="#Конверсия-пользователей,-удержание-пользователей." data-toc-modified-id="Конверсия-пользователей,-удержание-пользователей.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия пользователей, удержание пользователей.</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-каналам-привлечения-пользователей" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-каналам-привлечения-пользователей-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по каналам привлечения пользователей</a></span></li><li><span><a href="#Суммарные-доходы-от-пользователей--и-расходы-на-рекламу,-общая-рентабельность-за-весь-период-наблюдений-с-разбивкой-по-каналам." data-toc-modified-id="Суммарные-доходы-от-пользователей--и-расходы-на-рекламу,-общая-рентабельность-за-весь-период-наблюдений-с-разбивкой-по-каналам.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Суммарные доходы от пользователей  и расходы на рекламу, общая рентабельность за весь период наблюдений с разбивкой по каналам.</a></span></li><li><span><a href="#Распределение-рекламных-площадок-по-странам" data-toc-modified-id="Распределение-рекламных-площадок-по-странам-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Распределение рекламных площадок по странам</a></span></li><li><span><a href="#Распределение-клиентов-с-устройствами-по-странам." data-toc-modified-id="Распределение-клиентов-с-устройствами-по-странам.-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Распределение клиентов с устройствами по странам.</a></span></li><li><span><a href="#Распределение-рекламных-площадок-по-устройствам" data-toc-modified-id="Распределение-рекламных-площадок-по-устройствам-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Распределение рекламных площадок по устройствам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общие-выводы-по-проекту" data-toc-modified-id="Общие-выводы-по-проекту-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие выводы по проекту</a></span></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей приложения Procrastinate Pro+
#
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+.
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
# Ваша задача — разобраться в причинах и помочь компании выйти в плюс.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# 1. Лог сервера с данными об их посещениях.
# 2. Выгрузка их покупок за этот период.
# 3. Рекламные расходы.
#
# Вам предстоит изучить:
# 1. Откуда приходят пользователи и какими устройствами они пользуются?
# 2. Сколько стоит привлечение пользователей из различных рекламных каналов?
# 3. Сколько денег приносит каждый клиент?
# 4. Когда расходы на привлечение клиента окупаются?
# 5. Какие факторы мешают привлечению клиентов?

# %% [markdown]
# ### Загрузка данных и подготовка их к анализу

# %% [markdown]
#   #### Импорт библиотек.  Считывание данных из исходных файлов

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import copy
#import seaborn as sns
import numpy as np
from datetime import datetime, timedelta
#import scipy
#from scipy import stats as st

# %%
# считываем  данные и сохраняем в переменные

visits = pd.read_csv('visits_info_short.csv')  # визиты
orders = pd.read_csv('orders_info_short.csv')  # заказы
costs = pd.read_csv('costs_info_short.csv')  # расходы на рекламу

# %% [markdown]
# #### Общий обзор данных

# %% [markdown]
# Выводим первые строки и основную информацию  для  датасета визитов

# %%
# выводим первые строки  датасета и основную информацию
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Выводим первые строки и основную информацию  для  датасета заказов

# %%
# выводим первые строки  датасета и основную информацию
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.describe()
# Out:
#             User Id       Revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %%
# выводим  гистограмму 
orders['Revenue'].hist(bins = 100, figsize=(15,5))
plt.show()

# %% [markdown]
# Выводим первые строки и основную информацию  для датасета  стоимости рекламы

# %%
# выводим первые строки  датасета и основную информацию
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.describe()
# Out:
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000

# %%
# выводим  гистограмму 
costs.hist(bins = 100, figsize=(15,5))
plt.show()

# %% [markdown]
# **Общие замечания к данным:**
# 1. Названия столбцов в разных регистрах, в названиях столбцов есть пробелы.
# 2. Нет пропусков в данных.
# 3. Столбцы с датой следует привести к временному типу данных.
# 4. Сильная неравномерность в данных  по сумме заказа (revenue)  и  расходам на рекламную кампанию (costs)

# %% [markdown]
# #### Названия столбцов

# %% [markdown]
# Структура **visits**
#
# 1. User Id — уникальный идентификатор пользователя.
# 2. Region — страна пользователя.
# 3. Device — тип устройства пользователя.
# 4. Channel — идентификатор источника перехода.
# 5. Session Start — дата и время начала сессии.
# 6. Session End — дата и время окончания сессии.
#
#
#
# Структура **orders**
#
# 1. User Id — уникальный идентификатор пользователя,
# 2. Event Dt — дата и время покупки,
# 3. Revenue — сумма заказа.
#
#
#
# Структура **costs**
#
# 1. dt — дата проведения рекламной кампании,
# 2. Channel — идентификатор рекламного источника,
# 3. costs — расходы на эту кампанию.

# %% [markdown]
# Названия столбцов приводим к нижнему регистру и меняем пробел в названии на знак нижнего подчеркивания

# %%
# исходные названия столбцов датафрейма   visits
columns_initial = visits.columns
#print(columns_initial)


#приведение названий к нижнему регистру 
columns_final = columns_initial.str.lower()

#замена пробелов на нижнее подчеркивание
columns_final = columns_final.str.replace(' ','_')

#print(columns_final)


# создаем словарь для замены названий столбцов
columns_to_rename = dict(zip(columns_initial,columns_final))
#print(columns_to_rename)


#выполняем замену названий столбцов 
visits= visits.rename(columns = columns_to_rename)

#роверяем результат
visits.head(3)
# Out:
#         user_id         region  device  channel        session_start  \
# 0  981449118918  United States  iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States  iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States     Mac  organic  2019-05-01 14:09:25
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08

# %%
# исходные названия столбцов датафрейма   orders
columns_initial = orders.columns
#print(columns_initial)

#приведение названий к нижнему регистру
columns_final = columns_initial.str.lower()

#замена пробелов на нижнее подчеркивание
columns_final = columns_final.str.replace(' ','_')
#print(columns_final)

# создаем словарь для замены названий столбцов
columns_to_rename = dict(zip(columns_initial,columns_final))
#print(columns_to_rename)

#выполняем замену названий столбцов и проверяем результат
orders= orders.rename(columns = columns_to_rename)
orders.head(3)
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99

# %%
# исходные названия столбцов датафрейма   costs
columns_initial = costs.columns
#print(columns_initial)

#приведение названий к нижнему регистру
columns_final = columns_initial.str.lower()

#замена пробелов на нижнее подчеркивание
columns_final = columns_final.str.replace(' ','_')
#print(columns_final)

# создаем словарь для замены названий столбцов
columns_to_rename = dict(zip(columns_initial,columns_final))
#print(columns_to_rename)

#выполняем замену названий столбцов и проверяем результат
costs= costs.rename(columns = columns_to_rename)
costs.head(3)
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8

# %% [markdown]
# #### Преобразование  типов данных

# %%
# преобразование во временные типы данных 
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt'])

# %% [markdown]
# #### Проверка дубликатов

# %%
print('Количество дубликатов в visits: ', visits.duplicated().sum())
print('Количество дубликатов в orders: ', orders.duplicated().sum())
print('Количество дубликатов в costs: ', costs.duplicated().sum())
# Out:
# Количество дубликатов в visits:  0
# Количество дубликатов в orders:  0
# Количество дубликатов в costs:  0

# %% [markdown]
# Дубликатов в датасетах не обнаружено.

# %% [markdown]
# #### Обзор данных датасета

# %%
print('Количество уникальных пользователей - посетителей сайта:  ', visits['user_id'].nunique(), ' (', round(visits['user_id'].nunique()/visits['user_id'].count()*100, 2), '%)',  ', всего посетителей сайта: ',visits['user_id'].count()) 
print('Количество уникальных пользователей, разместивших заказ:  ', orders['user_id'].nunique(), ' (', round(orders['user_id'].nunique()/orders['user_id'].count()*100, 2), '%)',  ', всего количество заказов: ',orders['user_id'].count(),'\n')
# Out:
# Количество уникальных пользователей - посетителей сайта:   150008  ( 48.41 %) , всего посетителей сайта:  309901
# Количество уникальных пользователей, разместивших заказ:   8881  ( 22.09 %) , всего количество заказов:  40212

# %%
print('Рекламные кампании, всего: ', len(costs))
print('Рекламные кампании, разбивка по каналам:')
costs_g= costs.groupby(['channel'])['dt'].nunique()
print(costs_g, '\n')
# Out:
# Рекламные кампании, всего:  1800
# Рекламные кампании, разбивка по каналам:
# channel
# AdNonSense            180
# FaceBoom              180
# LeapBob               180
# MediaTornado          180
# OppleCreativeMedia    180
# RocketSuperAds        180
# TipTop                180
# WahooNetBanner        180
# YRabbit               180
# lambdaMediaAds        180
# Name: dt, dtype: int64

# %%
print('Количество стран пользователей:', visits['region'].nunique())
print('Cтраны пользователей:', visits['region'].unique(),'\n')
# Out:
# Количество стран пользователей: 4
# Cтраны пользователей: ['United States' 'UK' 'France' 'Germany']

# %%
print('Количество каналов привлечения пользователей:', visits['channel'].nunique())
print('Каналы привлечения пользователей:', visits['channel'].sort_values().unique(),'\n')
# Out:
# Количество каналов привлечения пользователей: 11
# Каналы привлечения пользователей: ['AdNonSense' 'FaceBoom' 'LeapBob' 'MediaTornado' 'OppleCreativeMedia'
#  'RocketSuperAds' 'TipTop' 'WahooNetBanner' 'YRabbit' 'lambdaMediaAds'
#  'organic']

# %%
print('Количество каналов рекламных кампаний:', costs['channel'].nunique())
print('Каналы рекламных кампаний:', costs['channel'].sort_values().unique(),'\n')
# Out:
# Количество каналов рекламных кампаний: 10
# Каналы рекламных кампаний: ['AdNonSense' 'FaceBoom' 'LeapBob' 'MediaTornado' 'OppleCreativeMedia'
#  'RocketSuperAds' 'TipTop' 'WahooNetBanner' 'YRabbit' 'lambdaMediaAds']

# %% [markdown]
# Временные рамки журнала пользователей

# %%
print('Минимальная дата начала сессии: ', visits['session_start'].min())
print('Максимальная дата начала сессии: ', visits['session_start'].max())
print('Максимальная дата окончания сессии: ', visits['session_end'].max())
delta = (visits['session_end'].max() - visits['session_start'].min()).days

print(f'Временное окно журнала пользователей, дней: {delta}.')
print()
# Out:
# Минимальная дата начала сессии:  2019-05-01 00:00:41
# Максимальная дата начала сессии:  2019-10-31 23:59:23
# Максимальная дата окончания сессии:  2019-11-01 01:38:46
# Временное окно журнала пользователей, дней: 184.

# %% [markdown]
# Временные рамки журнала заказов

# %%
print('Минимальная дата заказа: ', orders['event_dt'].min())
print('Максимальная дата заказа: ', orders['event_dt'].max())
delta = (orders['event_dt'].max() - orders['event_dt'].min()).days

print(f'Временное окно журнала заказов, дней: {delta}.')
print()
# Out:
# Минимальная дата заказа:  2019-05-01 00:28:11
# Максимальная дата заказа:  2019-10-31 23:56:56
# Временное окно журнала заказов, дней: 183.

# %% [markdown]
# Временные рамки рекламных кампаний

# %%
print('Минимальная дата рекламной кампании: ', costs['dt'].min())
print('Максимальная дата рекламной кампании: ', costs['dt'].max())
delta = (costs['dt'].max() - costs['dt'].min()).days

print(f'Временное окно рекламных кампаний, дней: {delta}.')
print()
# Out:
# Минимальная дата рекламной кампании:  2019-05-01 00:00:00
# Максимальная дата рекламной кампании:  2019-10-27 00:00:00
# Временное окно рекламных кампаний, дней: 179.

# %% [markdown]
# **Вывод по предобработке данных**
#
# 1. Названия столбцов приведены в нижний  регистр,  пробелы в названиях заменены на знаки нижнего подчеркивания.
# 2. Пропусков и дубликатов в датасетах нет.
# 3. В соответсвтующих столбцах данные приведены в формат даты.
# 4. Остальные типы данных соответсвуют представленным данным.
#
#
#
# **Обзор данных по датасету**
#
# 1. Количество уникальных пользователей - посетителей сайта:   150008, что составляет 48.41 % от всех посетителей сайта:  309901.
# 2. Количество уникальных пользователей, разместивших заказ:   8881, что составляет 22.09 % от всего количества заказов:  40212.
# 3. Рекламные кампании, всего:  1800,   равномерное распределение по 10 каналам привлечения пользователей, по 180 кампаний на канал. Перечень каналов в 'costs' совпадает со списком каналов в журнале пользователей.
# 4. Каналы рекламных кампаний: AdNonSense, FaceBoom, LeapBob, MediaTornado, OppleCreativeMedia, RocketSuperAds, TipTop, WahooNetBanner, YRabbit, lambdaMediaAds.
# 5. Пользователи представлены из 4 стран: USA, UK, France, Germany.
# 6. Первая сессия пользователя и первый заказ - 01 мая 2019, начало последней сессии и последний заказ - 31 октября 2019. Последняя сессия заканчивается 01 ноября 2019.  Временное окно по датам заказов и началам сессий - 183 дня.
# 7. Рекламные кампании начинаются 01 мая 2019 и заканчиваются 27 октября 2019, временное окно - 179 дней.
# 8. Минимальный заказ 4,99 у.е., максимальный заказ - 49,99 у.е.,  медианный заказ 4,99 у.е.
# 9. Минимальная стоимость рекламной кампании - 0,8 у.е., максимальная стоимость- 630 у.е., медианная-12,28  у.е..

# %% [markdown]
# ### Функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# Задаем функции для вычисления метрик и построения графиков

# %% [markdown]
# #### Функция для создания пользовательских профилей

# %%
# функция для создания пользовательских профилей


#def get_profiles(sessions, orders, events, ad_costs, event_names=[]):   #функционал на будущее, для учета событий в логах
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    ad_costs['dt'] = ad_costs['dt'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    
     #функционал на будущее    
#    # добавляем флаги для всех событий из event_names
#    for event in event_names:
#        if event in events['event_name'].unique():
#            profiles[event] = profiles['user_id'].isin(
#                events.query('event_name == @event')['user_id'].unique()
#            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Функция для расчёта удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # удаляем органиков
    profiles_except_org = profiles[profiles['channel']!='organic']
    
    
    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    
    result_raw = profiles_except_org.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### Функция для сглаживания фрейма (скользящее среднее)

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Функция для визуализации удержания

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для визуализации конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# #### Профили пользователей

# %% [markdown]
# Определяем профили пользователей с помощью предварительно определеной функции.

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
min_date_profiles = profiles['first_ts'].min()
print(f'Минимальная дата привлечения пользователя: {min_date_profiles }', '\n')
# Out:
# Минимальная дата привлечения пользователя: 2019-05-01 00:00:41

# %%
max_date_profiles = profiles['first_ts'].max()
print(f'Максимальная дата привлечения пользователя: {max_date_profiles }')
# Out:
# Максимальная дата привлечения пользователя: 2019-10-27 23:59:04

# %% [markdown]
# 1. Максимальная дата привлечения пользователя совпадает с датой последней рекламной кампании.
# 2. Даты записей в датасете соответсвтуют данным в задании.

# %% [markdown]
# #### Распределение пользователей по странам

# %%
print('Cтраны пользователей:', profiles['region'].unique(),'\n')
# Out:
# Cтраны пользователей: ['United States' 'France' 'Germany' 'UK']

# %% [markdown]
# Распределение платящих пользователей по странам.

# %%
reg_p =  profiles.pivot_table(index='region' , columns='payer', values ='user_id',
                              aggfunc='nunique').sort_values(by=True,ascending=False)
reg_p = reg_p.rename_axis(None, axis=1).reset_index()
reg_p = reg_p.rename(columns={False:'not_paying', True:'paying'})

reg_p['ratio paying/all_users, %'] = round(reg_p['paying']/(reg_p['paying']+reg_p['not_paying'])*100,2)
reg_p['ratio country/all_paying, %'] = round(reg_p['paying']/(reg_p['paying'].sum())*100,2)

reg_p
# Out:
#           region  not_paying  paying  ratio paying/all_users, %  \
# 0  United States       93100    6902                       6.90
# 1             UK       16875     700                       3.98
# 2         France       16787     663                       3.80
# 3        Germany       14365     616                       4.11
#
#    ratio country/all_paying, %
# 0                        77.72
# 1                         7.88
# 2                         7.47
# 3                         6.94

# %% [markdown]
# 1. Максимальное количество платящих пользователей - 6902 в США.  Неплатящих, кстати,  тоже в Соединенных Штатах больше, чем в других странах.
# 2. Платящие пользователи составляют 6,9 % от всех пользователей страны.  Это соотношение для США тоже самое высокое среди остальных стран.
# 3. Платящие пользователи в США составляют 77,72% от всех платящих пользователей приложения.

# %% [markdown]
# #### Распределение пользователей по устройствам

# %%
print('Устройства пользователей:', profiles['device'].unique(),'\n')
# Out:
# Устройства пользователей: ['Mac' 'iPhone' 'PC' 'Android']

# %% [markdown]
# Распределение платящих пользователей по устройствам.

# %%
dev_p =  profiles.pivot_table(index='device', columns='payer',
                              values ='user_id', aggfunc='nunique').sort_values(by=True,ascending=False)
dev_p = dev_p.rename_axis(None, axis=1).reset_index()
dev_p = dev_p.rename(columns={False:'not_paying', True:'paying'})

dev_p['ratio paying/all_users, %'] = round(dev_p['paying']/(dev_p['paying']+dev_p['not_paying'])*100,2)
dev_p['ratio country/all_paying, %'] = round(dev_p['paying']/(dev_p['paying'].sum())*100,2)

dev_p
# Out:
#     device  not_paying  paying  ratio paying/all_users, %  \
# 0   iPhone       51097    3382                       6.21
# 1  Android       32982    2050                       5.85
# 2      Mac       28130    1912                       6.36
# 3       PC       28918    1537                       5.05
#
#    ratio country/all_paying, %
# 0                        38.08
# 1                        23.08
# 2                        21.53
# 3                        17.31

# %% [markdown]
# 1. Самое предпочитаемое устройство - iPhone.
# 2. Количество платящих пользователей с iPhone - 3382, что составляет 6,21% от всех пользователей с этим устройством.
# 3. Платящие пользователи с iPhone составляют 38,08 % от всех платящих пользователей приложения.

# %% [markdown]
# #### Рекламные источники привлечения пользователей

# %%
print('Рекламные источники привлечения пользователей:','\n', profiles['channel'].sort_values().unique(),'\n')
# Out:
# Рекламные источники привлечения пользователей:
#  ['AdNonSense' 'FaceBoom' 'LeapBob' 'MediaTornado' 'OppleCreativeMedia'
#  'RocketSuperAds' 'TipTop' 'WahooNetBanner' 'YRabbit' 'lambdaMediaAds'
#  'organic']

# %% [markdown]
# Распределение платящих пользователей по источникам привлечения.

# %%
chan_p =  profiles.pivot_table(index='channel', columns='payer',
                              values ='user_id', aggfunc='nunique').sort_values(by=True,ascending=False)

chan_p = chan_p.rename_axis(None, axis=1).reset_index()

chan_p = chan_p.rename(columns={False:'not_paying', True:'paying'})

chan_p['ratio paying/all_users, %'] = round(chan_p['paying']/(chan_p['paying']+chan_p['not_paying'])*100,2)
chan_p['ratio cahnnel/all_paying, %'] = round(chan_p['paying']/(chan_p['paying'].sum())*100,2)

chan_p
# Out:
#                channel  not_paying  paying  ratio paying/all_users, %  \
# 0             FaceBoom       25587    3557                      12.20
# 1               TipTop       17683    1878                       9.60
# 2              organic       55279    1160                       2.06
# 3       WahooNetBanner        8100     453                       5.30
# 4           AdNonSense        3440     440                      11.34
# 5       RocketSuperAds        4096     352                       7.91
# 6              LeapBob        8291     262                       3.06
# 7   OppleCreativeMedia        8372     233                       2.71
# 8       lambdaMediaAds        1924     225                      10.47
# 9              YRabbit        4147     165                       3.83
# 10        MediaTornado        4208     156                       3.57
#
#     ratio cahnnel/all_paying, %
# 0                         40.05
# 1                         21.15
# ...

# %%
chan_p.sort_values(by='paying').plot(y=['paying', 'not_paying' ], x='channel', kind='barh', figsize=(15,10), grid= True,
                                                  title ='Рекламные источники привлечения пользователей, кол-во пользователей')
plt.show()

# %%
chan_p.sort_values(by='ratio paying/all_users, %').plot(y=['ratio paying/all_users, %' ], x='channel', kind='barh', figsize=(15,6),grid= True,
                                                  title ='Конверсия пользователей из всех пришедших в платящих по каналам')
plt.show()

# %% [markdown]
# 1. Самая высокая конверсия из пришедших пользователей в платящих  у FaceBoom (12.5 %).  TipTop занимает 4-е место по конверсии, а органики - последнее 10-е.
# 2. Платящие пользователи с FaceBoom составляют 40,05 % от всех платящих пользователей приложения, TipTop - 21.15 %  (61.2% в сумме с 1-м местом), при этом бесплатные  органики дают 13.06%  ( 74.26 % в сумме с 1-м и 2-м  местами).
# 3. Органические пользователи занимают 3-е место среди платящих и 1-е среди неплатящих.

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# #### Общие расходы на маркетинг

# %% [markdown]
# Общие расходы на маркетинг определим из файла с расходами на рекламу через суммирование расходов на все рекламные кампании

# %%
ad_costs_all = round(costs['costs'].sum(),2)
print(f'Общие расходы на маркетинг составляют {ad_costs_all}  у.е.')
# Out:
# Общие расходы на маркетинг составляют 105497.3  у.е.

# %%
revenue = round(orders['revenue'].sum(),2)
print(f'Общие доходы от пользователей  составляют {revenue}  у.е.')
# Out:
# Общие доходы от пользователей  составляют 215962.88  у.е.

# %% [markdown]
# #### Распределение расходов на маркетинг по рекламным источникам

# %%
costs_channel = costs.groupby('channel')['costs'].sum().reset_index()
costs_channel = costs_channel.sort_values(by='costs', ascending = False).reset_index(drop=True)
costs_channel = costs_channel.rename(columns = {'costs' : 'all_costs_ad'})
costs_channel['ratio channel/all_channel, %'] = round(costs_channel['all_costs_ad']/(costs_channel['all_costs_ad'].sum())*100,2)

costs_channel
# Out:
#               channel  all_costs_ad  ratio channel/all_channel, %
# 0              TipTop      54751.30                         51.90
# 1            FaceBoom      32445.60                         30.75
# 2      WahooNetBanner       5151.00                          4.88
# 3          AdNonSense       3911.25                          3.71
# 4  OppleCreativeMedia       2151.25                          2.04
# 5      RocketSuperAds       1833.00                          1.74
# 6             LeapBob       1797.60                          1.70
# 7      lambdaMediaAds       1557.60                          1.48
# 8        MediaTornado        954.48                          0.90
# 9             YRabbit        944.22                          0.90

# %%
costs_channel.sort_values(by='all_costs_ad').plot(y='all_costs_ad', x='channel', kind='barh', figsize=(15,6),grid= True,
                                                  title ='Распределение расходов на маркетинг по рекламным источникам, кол-во пользователей')
plt.show()

# %% [markdown]
# 1. Основная часть рекламного бюджета уходит на  "TipTop" (51.9 %) и "FaceBoom" (30.75 %).
# 2. На остальные 8 каналов остается только 17.35%  выделенных на рекламу денег. Практически принцип Парето: 20 % каналов расходуют больше 80% денег.
# 3. При таких суммарных расходах (82.65 %)  "TipTop" и "FaceBoom" дают всего 61,2% пользователей.

# %% [markdown]
# #### Динамика расходов на маркетинг по неделям и месяцам

# %% [markdown]
# Подготовка и обработка данных

# %%
#копируем датасет для свободной работы с данными
costs_date = copy.deepcopy(costs)

# меняем формат данных для столбца с датой
costs_date['dt'] = pd.to_datetime(costs_date['dt'])

# категоризиурем кампании по неделям и месяцам
costs_date['month'] =  costs_date['dt'].dt.month
costs_date['week'] =  costs_date['dt'].dt.isocalendar().week

# определяем расходы по рекламным источникам и неделям
costs_week = costs_date. pivot_table(index='week', columns='channel',
                              values ='costs', aggfunc='sum')
costs_week = costs_week.rename_axis(None, axis=1).reset_index()

# определяем расходы по рекламным источникам и месяцам
costs_month = costs_date. pivot_table(index='month', columns='channel',
                              values ='costs', aggfunc='sum')
costs_month = costs_month.rename_axis(None, axis=1).reset_index()

#перечень рекламных источников
quelle =  costs_date['channel'].sort_values().unique()

#print(quelle)

# %% [markdown]
# **Распределение расходов на маркетинг по каналам и  неделям**

# %%
costs_week
# Out:
#     week  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# 0     18      211.05     535.7    16.80         38.64               24.00
# 1     19      273.00     750.2    31.71         61.68               34.50
# 2     20      265.65     755.7    26.67         59.04               27.50
# 3     21      266.70     722.7    26.67         50.16               34.25
# 4     22      202.65    1208.9    65.52         36.96               81.75
# 5     23      102.90    1081.3    66.99         27.60               79.50
# 6     24       96.60    1042.8    52.29         29.76               71.50
# 7     25      141.75    1280.4    68.46         32.16               79.75
# 8     26      148.05    1647.8    99.75         40.56              107.00
# 9     27      130.20    1536.7    87.36         43.44              102.50
# 10    28      106.05    1124.2    62.58         28.80               81.00
# 11    29       97.65     975.7    61.11         26.40               68.00
# ...

# %%
costs_week.plot(x= 'week', y=quelle, figsize=(15,6), grid= True,
                                                  title ='Динамика расходов на маркетинг по каналам и неделям')
plt.show()

# %% [markdown]
# Посмотрим на отдельный срез каналов без FaceBoom и TipTop

# %%
#формируем срез
costs_week_cut = costs_week.drop(['TipTop', 'FaceBoom'], axis=1)
#costs_week_cut.head()
quelle_cut =['AdNonSense' , 'LeapBob', 'MediaTornado' ,'OppleCreativeMedia', 'RocketSuperAds', 'WahooNetBanner','YRabbit' ,'lambdaMediaAds']

#выводим график
costs_week_cut.plot(x= 'week', y=quelle_cut, figsize=(15,10), grid= True,
                                                  title ='Динамика расходов на маркетинг по неделям  и каналам без FaceBoom и TipTop ')
plt.show()

# %% [markdown]
# **Распределение расходов на маркетинг по каналам и  месяцам**

# %%
costs_month
# Out:
#    month  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# 0      5     1169.70    3524.4   140.28        238.56              169.75
# 1      6      538.65    5501.1   314.58        138.00              370.00
# 2      7      504.00    5294.3   313.53        138.48              366.50
# 3      8      579.60    6274.4   369.81        154.56              439.25
# 4      9      581.70    6114.9   343.98        144.72              427.75
# 5     10      537.60    5736.5   315.42        140.16              378.00
#
#    RocketSuperAds   TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# 0         577.980   2981.0           418.8   299.70           458.4
# 1         325.715   6675.6           921.0   106.20           199.2
# 2         252.070   8410.2           851.4    97.38           219.2
# 3         253.110  11202.0          1040.4   124.74           220.0
# 4         218.400  13232.5           977.4   152.79           247.2
# ...

# %%
costs_month.plot(x= 'month', y=quelle, figsize=(15,6), grid= True,
                                                  title ='Динамика расходов на маркетинг по каналам и месяцам')
plt.show()

# %% [markdown]
# Посмотрим на отдельный срез каналов без FaceBoom и TipTop

# %%
#формируем срез
costs_month_cut = costs_month.drop(['TipTop', 'FaceBoom'], axis=1)
#costs_month_cut.head()
quelle_cut =['AdNonSense' , 'LeapBob', 'MediaTornado' ,'OppleCreativeMedia', 'RocketSuperAds', 'WahooNetBanner','YRabbit' ,'lambdaMediaAds']

#выводим график
costs_month_cut.plot(x= 'month', y=quelle_cut, figsize=(15,11), grid= True,
                                                  title ='Динамика расходов на маркетинг по месяцам  и каналам без FaceBoom и TipTop ')
plt.show()

# %% [markdown]
# **Разбивка по неделям**
#
# 1. Лидируют как по величине, так и по росту стоимости расходов каналы  TipTop и FaceBoom.
# 2. Для этих каналов наблюдаются пики на 22, 26 и 39 неделях.  В основном наблюдается тренд на увеличение расходов с течением времени. На 29 и 42 неделях заметны провалы от освного тренда.
# 3. Остальные каналы относительно равномерно распределены  по исследуемому периоду.
# 4. Из них выделяются WahooNetBanner  и AdNoneSence.   Причем для WahooNetBanner с 18 по 26 недели наблюдается яркий контртренд на повышение стоимости привлечения клиентов.
#
#
# **Разбивка по месяцам**
#
# 1. Лидируют как по величине, так и по росту стоимости расходов каналы  TipTop и FaceBoom. Заметный тренд на увеличение стоимости с течением времени.
# 2. После сентября почти для вех каналов (искл. - YRabbit) наблюдается спад расходов на рекламу.
# 2. Для TipTop  наблюдается небольшое снижение роста в июле,  сильный пик в сентябре и спад в октябре.
# 3. FaceBoom показывает стремительный рост с мая по июнь, провал динамики в июле, мик в августе и  осеннее снижение расходов.
# 3. Остальные каналы относительно равномерно распределены  по исследуемому периоду.
# 4. Из них выделяются как и в понедлеьной разбивке WahooNetBanner  и AdNoneSence.   Причем для WahooNetBanner с мая по июнь наблюдается яркий контртренд на повышение стоимости привлечения клиентов.
# 5. В основном летом наблюдается спад (или снижение динамики) расходов на рекламу.

# %% [markdown]
# #### Средняя стоимость  привлечения одного пользователя (САС) по каналам

# %% [markdown]
# Подготовка и обработка данных

# %%
cac_avg_channel = profiles.groupby('channel').agg({'acquisition_cost':['mean','median']})

cac_avg_channel = cac_avg_channel.sort_values(by= ('acquisition_cost','mean'),ascending=False).reset_index()
cac_avg_channel
# Out:
#                channel acquisition_cost
#                                    mean    median
# 0               TipTop         2.799003  3.000000
# 1             FaceBoom         1.113286  1.114667
# 2           AdNonSense         1.008054  1.004348
# 3       lambdaMediaAds         0.724802  0.733333
# 4       WahooNetBanner         0.602245  0.600000
# 5       RocketSuperAds         0.412095  0.404444
# 6   OppleCreativeMedia         0.250000  0.250000
# 7              YRabbit         0.218975  0.214286
# 8         MediaTornado         0.218717  0.220926
# 9              LeapBob         0.210172  0.210000
# 10             organic         0.000000  0.000000

# %%
cac_avg_channel.sort_values(by=('acquisition_cost','mean')).plot(x='channel', y='acquisition_cost', 
                                      kind='barh', figsize=(15,6),grid= True,
                                      title ='Средняя и медианная стоимость  привлечения одного пользователя (САС) по каналам')
plt.show()

# %% [markdown]
# 1. По средней стоимости привелечения пользователя TipTop лидирует с отрывом в х2.5 от FaceBoom   и в три раза от AdNonSense.    TipTop - очень дорогой канал с  CAC ~= 3 у.е.
# 2. CAC около 1 у.е предлагают FaceBoom и  AdNonSense.
# 3. СAC в диапазоне 0,5-1 предлагают LamdaMediaAds и WahooNetBanner.

# %% [markdown]
# Сравним стоимость привлечения и количество привлеченных клиентов, определим эффективность привлечения клиентов.
# Эффективность привлечения клиентов по каналу  рассчитаем как отношение доли привлеченных платящих клиентов клиентов к средней стоимости привлечения.

# %%
#Собираем данные из разных таблиц 
scatter_channel = cac_avg_channel.merge(chan_p[['paying', 'channel','ratio cahnnel/all_paying, %']],on='channel' , how='left')

# причесываем результат
scatter_channel = scatter_channel.drop([('channel','' )], axis=1)
scatter_channel = scatter_channel.rename(columns={'channel':'Канал',
                                                   'paying':'Кол-во платящих пользователей',
                                                  ('acquisition_cost','mean'):'Средняя стоимость привлеч. клиента', 
                                                  ('acquisition_cost','median'):'Медианная стоимость привлеч. клиента',
                                                 'ratio cahnnel/all_paying, %':'Кол-во привлеч. платящих клиентов от всех платящих, %'})

#рассчитываем эффективность привлечения
scatter_channel['Эффективность привлечения, %/у.е']= scatter_channel['Кол-во привлеч. платящих клиентов от всех платящих, %']/scatter_channel['Средняя стоимость привлеч. клиента']

scatter_channel
# Out:
# C:\Users\МиО\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:648: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
#                  Канал  Средняя стоимость привлеч. клиента  \
# 0               TipTop                            2.799003
# 1             FaceBoom                            1.113286
# 2           AdNonSense                            1.008054
# 3       lambdaMediaAds                            0.724802
# 4       WahooNetBanner                            0.602245
# 5       RocketSuperAds                            0.412095
# 6   OppleCreativeMedia                            0.250000
# 7              YRabbit                            0.218975
# 8         MediaTornado                            0.218717
# 9              LeapBob                            0.210172
# 10             organic                            0.000000
#
# ...

# %%
scatter_channel.plot(x='Средняя стоимость привлеч. клиента', y='Кол-во платящих пользователей', kind='scatter', 
                     alpha = 1, figsize=(10,6), grid =True,
                     title ='Зависимость стоимости привлечения от количества платящих пользователей')
plt.show()

# %% [markdown]
# Для корректной визуализации расчета исключим орагнический канал привлечения клиентов, у них эффектнивность стремится к бесконечности)

# %%
scatter_channel.loc[0:9].sort_values(by= 'Эффективность привлечения, %/у.е').plot(x='Канал', 
                                    y ='Эффективность привлечения, %/у.е', kind='barh', figsize=(15,6), grid =True,
                                    title ='Эффективность привлечения клиентов по каналам')
plt.show()

# %% [markdown]
# Интересные выводы получаются:
# 1. Большинство каналов привлечения в абсолютных цифрах по количеству привлеченных пользователей работает хуже, чем бесплатный organic.
# 2. Самый дорогой TipTop привлекает клиентов, их количество занимает второе место по каналам,  но его эффективность ниже не только, чем у FaceBoom, но почти всех остальных тоже.
# 3. Явный лидер по эффективности вложения средств- FaceBoom. На 1 вложенный у.е. он приносит 35% платящих пользователей.
# 4. Хорошие относительные показатели у LeapBob и OppleCreativeMedia.  Но в абсолютных цифрах результаты скромнее, впрочем как и затраченные средства  на рекламу в этих каналах.

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# ####   Графики   LTV, CAC, ROI.    Окупаемость рекламы.

# %% [markdown]
# Рассчитаем и визуализируем LTV и ROI.

# %%
#Из задания определяем дату наблюдений (момент анализа) - 01.11.2019,  горизонт анализа - 14 дней.
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# по умолчанию окно для скользящего среднего window = 7 дням

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Неутешительные выводы.
# 1. Общий ROI не достигает 1, т.о. на 14-й день в среднем за весь период наблюдений окупаемости рекламы не происходит.
# 2. Динамика ROI показывает, что окупаемость рекламы была до середины июня с небольшим провалом в начале июня.  А дальше- полный слив рекламного бюджета.
# 3. Если увеличить горизонт анализа, то заметно, что средний ROI достиагет окупаемости на 21-й лайфтайм, но это выходит за рамки бизнес-плана.
# 4. Наблюдются сезонные пики (ближе к середине месяца)  и провалы LTV- в основном к концу месяца. Октябрь в контртренде сезонности.

# %% [markdown]
# Учитывая дороговизну рекламных кампаний в TipTop и обнаруженную низкую эффективность этого канала привлечения, то посмотрим отдельно на пользователей из этого канала и отдельно на всех остальных.

# %% [markdown]
# **Только пользователи, пришедшие из TipTop**

# %%
profiles_only_tiptop = profiles[profiles['channel']=='TipTop']
#profiles_only_tiptop

# %%
# временные рамки
horizon_days = 14
# по умолчанию окно для скользящего среднего window = 7 дням

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_only_tiptop, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# 1. За необходимые две недели инвестиции  в среднем не окупаются, расходы на рекламу практически в два раза больше доходов от пользователей.
# 2. Окупаемость достигается на 36-й лайфтайм, что непозолительно больше заложенного периода в бизнес-плане.
# 3. Стоимость привлечения клиента стабильно ежемесячно повышается, на большей части наблюдаемого периода CAC выше LTV, а ROI, как следствие,  выше единицы только до середины мая (пока не произошло повышение CAC) и небольшой период в июне.

# %% [markdown]
# **Пользователи, пришедшие НЕ из TipTop**

# %%
profiles_except_tiptop = profiles[profiles['channel']!='TipTop']
#profiles_except_tiptop

# %%
# временные рамки
horizon_days = 14
# по умолчанию окно для скользящего среднего window = 7 дням

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_except_tiptop, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# 1. Окупаемость рекламы достигается на 9-й лайфтайм из 14-ти запланированных.
# 2. Динамический обзор показыват не стабильную окупаемость рекламы на всем промежутке наблюдений.

# %% [markdown]
# Детальнее на окупаемость рекламы с разбивкой пользователей на группы посмотрим в следующих пунктах. На текущий момент- TipTop - первый и главный кандидат на исключение из рекламного бюджета.

# %% [markdown]
# ####   Конверсия пользователей, удержание пользователей.

# %% [markdown]
# Для расчета удержания и конверсии пользователей, визуализации данных вызовем соответствующие функции.
# Дата анализа остается прежней. Горизонт анализа задаем согласно задания - 14 дней

# %%
# временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# считаем CR
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, ignore_horizon=False)

# считаем RR
retention_raw, retention, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days,  ignore_horizon=False)


#строим графики
plot_conversion(conversion, conversion_history, horizon_days, window=14)
plot_retention(retention, retention_history, horizon_days, window=14)

# %% [markdown]
# **Посмотрим на распределение коэффициентов удержания и конверсии в разбивке по каналам привлечения.**

# %% [markdown]
# - Сгруппируем пользователей по каналам привлечения пользователей.
# - Рассчитаем и визуализируем LTV и ROI.
# - Учет пользователей-органиков выполняется в функции расчета ROI.
# - Для группировки пользователей в функцию расчета передадим параметр группировки

# %%
# временные рамки
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

#параметр группировки 
parametr = ['channel']

# считаем CR
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# считаем RR
retention_raw, retention, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)


#строим графики
plot_conversion(conversion, conversion_history, horizon_days, window=28)
plot_retention(retention, retention_history, horizon_days, window=28)

# %% [markdown]
# **Конверсия**
# 1. Усредненная конверсия со 2 дня находится в диапазоне 5-5,7 %.
# 2. На протяжении исследумого периода на 14-й день конверсия с июня стабильно выше 5% и в некоторых случаях выше 6,5%.
# 3. Наблюдются сезонные пики (ближе к середине месяца)  и провалы конверсии- в основном к концу месяца.
# 4. Сезонность конверсии коррелирует с сезонностью LTV. Пользователи, пришедшие в начале месяца показывают большую конверсию и доход, чем пришедшие в середине месяца.
#
#
# **Удержание**
#
# 1. Удержание платящих пользователей (в диапазоне c 40 до 12%)  кратно выше удержания неплатящих пользователей (в диапазоне  с 17% до <1%).
# 2. На 9-м лайфтайме график удержания  идет горизонтально - нет оттока платящих пользователей.
# 3. Динамика удержания платящих пользователей  на конец горизонта анализа (14-й день) подверженна сезонности и находится в диапазоне 17,5 % - 7,5%.
# 4. Неплатящие пользователи на 14-й день относительно стабильно отскакивают в течении всего времени наблюдений- удержание очень низкое, до 1%.
#
# **Разбивка по каналам**
#
# *Конверсия*
#
# 1.FaceBoom показывает самую высокую конверсию (около 12%).
# 2. TipTop на 4-м месте по конверсии и выше среднего (около 9%).
# 3. Худшая конверсия у органиков (около 2%).
#
# *Удержание*
# 1. Самое низкое удержание у FaceBoom как в среднем, так и в диниамике.
# 2. Удержание платящих пользователей у органиков тоже низкое (предпоследнее место).
# 3. TipTop по удерживанию платящих пользователей идет середнячком.
# 4. В удержании неплатящих пользователей как в среднем, так и в динамике каналы привлечения показывают похожую картину.

# %% [markdown]
# ####   Окупаемость рекламы с разбивкой по устройствам

# %% [markdown]
# - Сгруппируем пользователей по устройствам.
# - Рассчитаем и визуализируем LTV и ROI.
# - Учет пользователей-органиков выполняется в функции расчета ROI.
# - Для группировки пользователей в функцию расчета передадим параметр группировки

# %%
#временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# для повышения читаемости графиков установим окно для скользящего среднего window = 28 дням

#параметр группировки 
parametr = ['device']

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=28)

# %% [markdown]
# Посмотрим на такую же группировку только без пользователей с нерентабельных каналов

# %%
#временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# для повышения читаемости графиков установим окно для скользящего среднего window = 28 дням

#выделим пользователей с рентабельных каналов
profiles_except = profiles[~profiles['channel'].isin(['TipTop', 'FaceBoom', 'AdNonSense'])]
#print(profiles_except_tiptop)
 
#параметр группировки 
parametr = ['device']

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_except, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=28)

# %% [markdown]
# **Все пользователи с группировкой по устройствам**
#
# Динамика что LTV, что ROI сильно неравномерна, для повышения читаемости графика окно сглаживания для функции скользящего среднего увеличено до 28 дней.
#
#
# *PC*
# 1. Пользователи с PC показывают меньший средний LTV на всем горизонте анализа, но так же и меньшую стоимость привлечения клиента.
# 2. Окупаемость рекламы для пользователей PC наступает раньше всех, на 11-й лайфтайм, к концу первой недели.
#
#
# *Android*
# 1. Пользователи с Android обнаруживают средние показатели как по стомости привлечения клиентов, так и по окупаемости.
# 2. Реклама с Android не окупается к 14 дню.
#
# *Apple (Mac и iPhone)*
# 1. Пользователи с техникой от Apple показывают синхронность в LTV, CAC, ROI как в общем, так и в динамике.
# 2. Немного выше в этой паре преобладают пользователи Mac.
# 3. Яблочные пользователи с одной стороны приносят больше всего дохода, но и затраты на их привлечение также выше, чем для остальных пользователей.
# 4. Динамика роста CAC для  пользователей этой группы выше, как и стремительнее падение окупаемости со временем.
# 5. Средняя окупаемость достигает  единицы  только к 30 лайфтайму, что больше, чем заложено в бизнес плане. В течение запланированных двух недель яблочные пользователи не окупают вложенных средств.
#
#
# **Группировка по устройствам без пользователей c нерентабельных каналов**
#
# 1. Наблюдаются сильные положительные изменения.
# 2. Средний LTV падает, но еще сильнее падают расходы на привлечение клиентов.
# 3. Самые дорогие Apple становятся самыми дешевыми в привлечении.
# 4. Динамика LTV на 14 лайфтайм для Mac и iPhone находится в контртренде.
# 5. На всем протяжении наблюдаемого периода реклама окупается даже для Apple.
# 6. Средний ROI становится выше уровня окупаемости уже ко 4-му лайфтайму для всех клиентов.

# %% [markdown]
# ####   Окупаемость рекламы с разбивкой по странам

# %% [markdown]
# - Сгруппируем пользователей по странам.
# - Рассчитаем и визуализируем LTV и ROI.
# - Учет пользователей-органиков выполняется в функции расчета ROI.
# - Для группировки пользователей в функцию расчета передадим параметр группировки

# %%
#временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# для повышения читаемости графиков установим окно для скользящего среднего window = 14 дням

#параметр группировки 
parametr = ['region']

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=28)

# %% [markdown]
# Посмотрим на такую же группировку только без пользователей с нерентабельных каналов

# %%
#временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# для повышения читаемости графиков установим окно для скользящего среднего window = 28 дням

#выделим пользователей с рентабельных каналов
profiles_except = profiles[~profiles['channel'].isin(['TipTop', 'FaceBoom', 'AdNonSense'])]
#print(profiles_except_tiptop)

#параметр группировки 
parametr = ['region']

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_except, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=28)

# %% [markdown]
# **Все пользователи с группировкой по странам**
#
# 1. На горизонте анализа максимальный LTV, с ощутимым отрывом показывают США. Минимальный LTV  у Франции.  Германия и Великобритания показывают близкие средние значения.
# 2. На протяжении наблюдаемого периода  по динамике LTV  страны представлены в таком же порядке.
# 3. По стоиомсти привлечения пользователей с огромным отрывом лидируют США.  Остальные страны проявлют солидарность и показывают близкие низкие уровни CAC.
# 4. ROI  для США на горизонте анализа в 14 дней не достигает уровня окупаемости.  В динамике ROI выше 1 только до конца мая.
# 5. Остальные страны в среднем выходят на окупаемость к 4-му лайфтайму, а динамика ROI на 14-й день для остальных стран выше уровня окупаемости на всем периоде наблюдения.
#
#
#
# **Группировка по странам без пользователей c нерентабельных каналов**
#
# 1. Великобритания занимает первое место по LTV как на горизонте анализа, так и в динамике на 14-й день.
# 2. У США  самая низкая СAС и, при этом, самая высокая рентабельность- они в плюсе со 2-го лайфтайма.
# 2. По LTV США смешаются на торое место, Германия- на третье  Франция на последнем месте.
# 3. Для стран, кроме США, САС примерно одинаковый, снижается  концу июля и дальше до ноября стабилен.
# 4. На горизонте анализа рентабельность для всех стран проходит уровень окупаемости к 5-му дню и на 14й день ROI стабильно выше 1

# %% [markdown]
# ####   Окупаемость рекламы с разбивкой по каналам привлечения пользователей

# %% [markdown]
# - Сгруппируем пользователей по каналам привлечения пользователей.
# - Рассчитаем и визуализируем LTV и ROI.
# - Учет пользователей-органиков выполняется в функции расчета ROI.
# - Для группировки пользователей в функцию расчета передадим параметр группировки

# %%
#временные рамки
#observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
# для повышения читаемости графиков установим окно для скользящего среднего window = 28 дням

#параметр группировки 
parametr = ['channel']

#вызываем функцию расчета LTV, ROI, CAC
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions= parametr, ignore_horizon=False)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=28)

# %% [markdown]
# **LTV**
#
# 1. Максимальный LTV обнаруживает lambdaMediaAds и TipTop. У этих каналов и высокая сезонность в динамике LTV на 14-й день.
# 2. Минимальный LTV у органиков, предпоследнее место - OppleCreativeMedia.
# 3. Средние уровни LTV показывают FaceBoom, AdNonSense и RocketSuperAds.
#
#
# **CAC**
#
# 1. Очень высокая CAC у TipTop с постоянным ежемесячным повышением с мая по октябрь.
# 2. Второе место по дороговизне у FaceBoom, но стоимость неизменна на всем протяжении наблюдений.
# 3. Самая низкая САС у YRabbit и MediaTornado.
#
#
# **ROI**
#
# 1. FaceBoom и AdNonSense вообще не выходят на окупаемость за весь период наблюдений.
# 2. ROI  TipTop выходит на уровень окупаемости после 20-го лайфтайма. А на 14-й лайфтайм реклама окупается только до начала июня.
# 3. Первое место по ROI  у YRabbit ,  2 и 3-е места у MediaTornado и lambdaMediaAds соответственно.

# %% [markdown]
# ####   Суммарные доходы от пользователей  и расходы на рекламу, общая рентабельность за весь период наблюдений с разбивкой по каналам.

# %% [markdown]
# Посмотрим на суммарные доходы и расходы по каналам привлечения пользователей.
# Определим общую рентабельность за весь период наблюдений.

# %%
ad_costs_all = round(costs['costs'].sum(),2)
print(f'Общие расходы на маркетинг составляют {ad_costs_all}  у.е.')
# Out:
# Общие расходы на маркетинг составляют 105497.3  у.е.

# %%
revenue = round(orders['revenue'].sum(),2)
print(f'Общие доходы от пользователей  составляют {revenue}  у.е.')
# Out:
# Общие доходы от пользователей  составляют 215962.88  у.е.

# %%
benefit = round(revenue-ad_costs_all ,2)
print(f'Общая прибыль от пользователей  составляет {benefit}  у.е.')
# Out:
# Общая прибыль от пользователей  составляет 110465.58  у.е.

# %%
roi = round(revenue/ad_costs_all*100,2)
print(f'Общая рентабельность инвестиций составляет {roi}  %.')
# Out:
# Общая рентабельность инвестиций составляет 204.71  %.

# %% [markdown]
# Посмотрим на суммарные доход/расходы, ROI и  прибыль за весь период в разбивке по каналам

# %%
# Дополняем таблицу заказов информацией о каналах привлечения клиентов
intermediate = orders.merge(profiles[['channel', 'user_id', 'region', 'device']], on='user_id', how = 'left' )

# ... группируем по каналам привлечения
all_period = intermediate.pivot_table(index = 'channel', values =['revenue' ],aggfunc='sum')
all_ads  = costs.pivot_table(index = 'channel', values =['costs' ],aggfunc='sum')

#причесываем таблицу после группировки
all_period = all_period.rename_axis(None, axis=1).reset_index()
all_ads =all_ads.rename_axis(None, axis=1).reset_index()

#объединяем данные и заполняем пропуск в расходах на рекламу у орагников
all_period = all_period.merge(all_ads[['costs','channel']], on= 'channel', how = 'left').fillna(0)


all_period['general_ROI'] = all_period['revenue']/all_period['costs']

# удаляем строки с бесконечным ROI
#all_period = all_period[~all_period['general_ROI'].isin([np.inf])]

#добавляем столбец с доходом
all_period['benefit'] = all_period['revenue']-all_period['costs']
benefit_sum = all_period['benefit'].sum()
               
all_period['ratio_benefit'] = all_period['benefit']/benefit_sum*100

# сортируем результат по ROI
all_period = all_period.sort_values(by = 'general_ROI', ascending= False).reset_index(drop=True)

all_period
# Out:
#                channel   revenue     costs  general_ROI   benefit  \
# 0              organic  46627.23      0.00          inf  46627.23
# 1              YRabbit   6201.43    944.22     6.567781   5257.21
# 2       RocketSuperAds  11598.32   1833.00     6.327507   9765.32
# 3         MediaTornado   5752.32    954.48     6.026653   4797.84
# 4       lambdaMediaAds   8941.70   1557.60     5.740691   7384.10
# 5              LeapBob   9560.13   1797.60     5.318274   7762.53
# 6   OppleCreativeMedia   8365.53   2151.25     3.888683   6214.28
# 7       WahooNetBanner  20006.63   5151.00     3.884028  14855.63
# 8               TipTop  69574.76  54751.30     1.270742  14823.46
# 9           AdNonSense   3697.17   3911.25     0.945266   -214.08
# 10            FaceBoom  25637.66  32445.60     0.790174  -6807.94
#
#     ratio_benefit
# 0       42.209736
# 1        4.759139
# 2        8.840147
# 3        4.343290
# 4        6.684526
# 5        7.027103
# 6        5.625535
# ...

# %%
all_period.sort_values(by='revenue').plot(y=['revenue', 'costs' ], x='channel', kind='barh', figsize=(12,6), grid= True,
                                                  title ='Соотношение доходов и расходов по рекламным каналам')
plt.show()

# %%
# удаляем строки с бесконечным ROI
#all_period = all_period[~all_period['general_ROI'].isin([np.inf])]

all_period[~all_period['general_ROI'].isin([np.inf])].sort_values(by='general_ROI').plot(y=['general_ROI' ], x='channel', kind='barh', figsize=(12,6), grid= True,
                                                  title ='Суммарная рентабельность инвестиций по рекламным каналам за период')
plt.show()

# %%
all_period.sort_values(by='benefit').plot(y=['benefit' ], x='channel', kind='barh', figsize=(12,6), grid= True,
                                                  title ='Суммарный доход (SumRevenue-SumCosts) по рекламным каналам за период')
plt.show()

# %%
#Определяем доходность по каналам
non_roi_cnannel = all_period[all_period['general_ROI']<1]['benefit'].sum()
good_roi_cnannel = all_period[all_period['general_ROI']>=1]['benefit'].sum()
organic = all_period[all_period['channel']=='organic']['benefit'].sum()
total_benefit = all_period['benefit'].sum()

print(f'Суммарная прибыль от каналов с ROI на уровне или выше окупаемости:  {round(good_roi_cnannel, 2)}  у.е.')
print(f'Суммарная прибыль от каналов с ROI на ниже уровня окупаемости:  {round(non_roi_cnannel, 2)}  у.е.')
print(f'Суммарная прибыль от всех каналов:  {round(good_roi_cnannel+non_roi_cnannel, 2)}  у.е.','\n')
print(f'Отношение прибыли от каналов с ROI < 1 к прибыли каналов с ROI >=1:  {round((1-non_roi_cnannel)/good_roi_cnannel*100, 2)} %.')
print(f'Доля прибыли с клиентов-органиков  от прибыли со всех каналов:  {round(organic/total_benefit*100, 2)} %.')
# Out:
# Суммарная прибыль от каналов с ROI на уровне или выше окупаемости:  117487.6  у.е.
# Суммарная прибыль от каналов с ROI на ниже уровня окупаемости:  -7022.02  у.е.
# Суммарная прибыль от всех каналов:  110465.58  у.е.
#
# Отношение прибыли от каналов с ROI < 1 к прибыли каналов с ROI >=1:  5.98 %.
# Доля прибыли с клиентов-органиков  от прибыли со всех каналов:  42.21 %.

# %% [markdown]
# Удалим нерентабельные каналы  и посмотрим на общую прибыльность.

# %%
all_period_except =all_period [~all_period['channel'].isin(['FaceBoom', 'AdNonSense'])]

#Определяем доходность по каналам
non_roi_cnannel = all_period_except[all_period_except['general_ROI']<1]['benefit'].sum()
good_roi_cnannel = all_period_except[all_period_except['general_ROI']>=1]['benefit'].sum()
organic = all_period_except[all_period_except['channel']=='organic']['benefit'].sum()
total_benefit = all_period_except['benefit'].sum()

total_revenue = all_period_except['revenue'].sum()
total_costs = all_period_except['costs'].sum()

print(f'Суммарная прибыль от каналов с ROI на уровне или выше окупаемости:  {round(good_roi_cnannel, 2)}  у.е.')
print(f'Суммарная прибыль от всех каналов:  {round(good_roi_cnannel+non_roi_cnannel, 2)}  у.е.','\n')

print(f'Доля прибыли с клиентов-органиков  от прибыли со всех каналов:  {round(organic/total_benefit*100, 2)} %.','\n')

print(f'Общая рентабельность:  {round(total_revenue/total_costs*100, 2)} %.')
# Out:
# Суммарная прибыль от каналов с ROI на уровне или выше окупаемости:  117487.6  у.е.
# Суммарная прибыль от всех каналов:  117487.6  у.е.
#
# Доля прибыли с клиентов-органиков  от прибыли со всех каналов:  39.69 %.
#
# Общая рентабельность:  269.93 %.

# %% [markdown]
# **Выводы за весь период наблюдений**
#
# Если отойти от определенного в задании периода окупаемости в 14 дней и учесть весь период наблюдений, то получается интересная картина.
#
# 1. Игра в долгую совершенно меняет подход к инвестициям, по-другому позволяет посмотреть на результат вложений и оценку деятельности бизнеса.
# 2. Важно также смотреть не только на относительные метрики, но и на абсолютные значения измерямых параметров.
# 3. Топовый по доходам и количеству клинтов TipTop в результате покажет скромную прибыль (3-е место в абсолютных цифрах).
# 4. Второй по доходам FaceBoom на долгой дистанции в сумме генерирует убытки. Как и AdNonSense. За счет низкого удержания у этих каналов, в долгосрочном периоде инвестиции в рекламу не окупаются.
# 5. Бесплатные (по прямым расходам на рекламу)  органические пользователи принесли прибыли больше, чем любой из платных каналов, а в целом прибыль по органическому каналу составляет 42,21% от всей прибыли!
# 6. Если полностью убрать расходы на нерентабельные каналы (FaceBoom, AdNonSense), то, с учетом отсутствия доходов с этих каналов,  общая прибыль вырастет на ~ 7000, а общая рентабельность с 205% вырастет до 270%.

# %% [markdown]
# ####   Распределение рекламных площадок по странам

# %%
channel = intermediate.pivot_table(index = 'channel', columns = 'region', values= 'user_id', aggfunc='count'). fillna(0)
#причесываем таблицу после группировки
channel = channel.rename_axis(None, axis=1).reset_index()

channel
# Out:
#                channel  France  Germany      UK  United States
# 0           AdNonSense   220.0    232.0   231.0            0.0
# 1             FaceBoom     0.0      0.0     0.0         4734.0
# 2              LeapBob   616.0    446.0   725.0            0.0
# 3         MediaTornado     0.0      0.0     0.0         1068.0
# 4   OppleCreativeMedia   506.0    406.0   635.0            0.0
# 5       RocketSuperAds     0.0      0.0     0.0         2168.0
# 6               TipTop     0.0      0.0     0.0        13024.0
# 7       WahooNetBanner  1264.0   1211.0  1262.0            0.0
# 8              YRabbit     0.0      0.0     0.0         1157.0
# 9       lambdaMediaAds   572.0    477.0   581.0            0.0
# 10             organic   844.0    972.0  1034.0         5827.0

# %%
channel.plot(y=['France', 'Germany', 'UK', 'United States' ], x='channel', kind='barh', figsize=(12,6), grid= True,
                                                  title ='Соотношение количества клиентов с устройствами по странам')
plt.show()

# %% [markdown]
# 1. Сильная сегрегация площадок по странам: Европейские площадки не представлены в США и наоборот.
# 2. Только сарафанное радио  и свободный поиск органиков присутствует везде. Значительная доля органиков из USA.
# 3. Площадки USA:   FaceBoom,  MediaTornado, RocketSuperAds, TipTop, YRabbit.
# 4. Европейские площадки: AdNonSense, LeapBob, OppleCreativeMedia, WahooNetBanner, lambdaMediaAds.

# %% [markdown]
# ####   Распределение клиентов с устройствами по странам.

# %%
device = intermediate.pivot_table(index = 'device', columns = 'region', values= 'user_id', aggfunc='count'). fillna(0)

#причесываем таблицу после группировки
device = device.rename_axis(None, axis=1).reset_index()

device
# Out:
#     device  France  Germany    UK  United States
# 0  Android    1098     1145  1334           5960
# 1      Mac     484      388   388           6740
# 2       PC    1688     1550  1871           2945
# 3   iPhone     752      661   875          12333

# %%
device.plot(y=['France', 'Germany', 'UK', 'United States' ], x='device', kind='barh', figsize=(12,6), grid= True,
                                                  title ='Соотношение количества клиентов с устройствами по странам')
plt.show()

# %% [markdown]
# 1. В целом заметно преобладание количества клиентов из USA.
# 2. Для USA преобладает доля клиентов с устройствами Apple.  На третьем месте Android с хорошей позицией.
# 3. Для Европы преобладающим устройством будет PC, на втором месте - Android.

# %% [markdown]
# ####   Распределение рекламных площадок по устройствам

# %%
ch_device = intermediate.pivot_table(index = 'channel', columns = 'device', values= 'user_id', aggfunc='count'). fillna(0)

#причесываем таблицу после группировки
ch_device = ch_device.rename_axis(None, axis=1).reset_index()

ch_device
# Out:
#                channel  Android   Mac    PC  iPhone
# 0           AdNonSense      176    64   298     145
# 1             FaceBoom     1040  1169   509    2016
# 2              LeapBob      572   201   746     268
# 3         MediaTornado      179   318   118     453
# 4   OppleCreativeMedia      364   205   613     365
# 5       RocketSuperAds      316   604   196    1052
# 6               TipTop     2946  2884  1389    5805
# 7       WahooNetBanner     1220   318  1591     608
# 8              YRabbit      274   308   133     442
# 9       lambdaMediaAds      414   168   655     393
# 10             organic     2036  1761  1806    3074

# %%
ch_device.plot(y=['Android', 'Mac', 'PC', 'iPhone' ], x='channel', kind='barh', figsize=(12,8), grid= True,
                                                  title ='Соотношение количества клиентов с устройствами по каналам')
plt.show()

# %% [markdown]
# 1. Все устройства представлены на каждой из площадок.
# 2. На американских площадках преобладают iPhone, но доля клиентов с другими устройствами также значительна.

# %% [markdown]
# ####   Выводы

# %% [markdown]
# *Окупаемость  рекламы в целом*
#
# 1. Для заданного двухнедельного периода окупаемость не выполняется.
# 2. Усредненная рентабельность инвестиций достигает уровня окупаемости на 15-й лайфтайм.
# 3. Если рассматривать эффективность бизнеса на длительном промежутке, то общая ROI достигнет 2,05.
#
#
# *Устройства, страны и рекламные каналы оказывающие негативное влияние на окупаемость рекламы*
#
# 1. Основным негативным фактором, влияющим на окупаемость рекламы является рекламный канал. Клиенты с каналов FaceBoom и AdNonSense вообще не выходят на окупаемость за весь период наблюдений. TipTop выходит на уровень окупаемости после 20-го лайфтайма.
# 2. Если смотреть в общем на всех пользователей без фильтрации, то на снижение рентабельности влияют клиенты из США и клиенты с устройствами от Apple.
# 3. Но если отфильтровать клиентов из нерентабельных  каналов, то проблемы у яблочных клиентов из США исчезают.
#
#
# *Причины проблем с окупаемостью*
#
# 1. Сверхдорогая реклама в TipTop.
# 2. Низкое удержание клиентов у FaceBoom.
# 3. Слишком короткий заданный период окупаемости.
# 4. Веерное распределение рекламного бюджета по рекламным площадкам без учета особенностей каждой площадки.
# 5. Ковровая рекламная кампания без учета сезонности.
# 6. Единая стоимость приложения для всех.
#
#
#
# *Предварительные рекомендации*
#
# 1. Увеличить планируемый период окупаемости. Динамика ROI на 35-й день на всем протяжении наблюдаемого периода выше уровня окупаемости для всех пользователей.
# 2. Проработать возможность увеличения удержания клиентов у  FaceBoom. Если это невозможно или нерационально, то следует отказаться от этой площадки.
# 3. Проработать вопрос снижения стоимости рекламы в TipTop. Сверхдорогая реклама сильно роняет рентабельность инвестиций для канала с высоким потоком клиентов и хорошим удержанием.
# 4. Настраивать рекламные кампании с учетом сезонности, в идеале- анализировать каждый канал и настраивать кампании индивидуально.
# 5. Провести работу над увеличением потока органических клиентов, их конверсией и удержанием. Такая категория клиентов генерирует хорошую прибыль. Неплатящих пользователей -органиков больше, чем  с любого другого канала. А прибыль (доход-расход на рекламу) от платящих органиков составляет 42 % от всей генерируемой прибыли.
# 6. Ввести гибкую ценовую политику в зависимости от рекламного канала.  Этот момент особенно касается клиентов, пришедших через FaceBoom или TipTop. Их стоимость привлечения самая высокая,  такие клиенты генерируют высокий денежный поток, но рентабельность если превышает уровнень окупаемости, то не сильно.

# %% [markdown]
# ### Общие выводы по проекту
#
#
#
# - Невнимательное отношение к рекламным кампаниям,  желание быть в мейнстриме не приводит к высокой прибыли. К широкому денежному потоку- возможно, но не к высокой прибыли.
# - Стремление к быстрому возврату инвестиций (двухнедельный срок окупаемости) может быть причиной некорректного анализа бизнес-процессов.
# - Для повышения как рентабельностий инвестиций, так и увеличения прибыли в абсолютных цифрах следует играть вдолгую, в том числе- анализировать процессы на длительном промежутке времени.
# - Рекламные кампании следует проектировать с учетом характеристик каждой платформы, сезонности, стоимости привлечения и размера дохода, результирующей прибыли, а также величины удержания и конверсии.
# - Отдельное внимание следует уделить органическим клиентам, особенно повышению их конверсии и удержанию. Они генерируют хорошую прибыль, у них нулевые затраты на рекламу, а  количество неплатящих пользователей больше, чем у любого платного канала.
# - Следует проработать вопрос гибкой ценовой политики для разных платформ, которые сильно сегментированы по регионам и существенно отличаются стоимостью привлечения клиентов.
